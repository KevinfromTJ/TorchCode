# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/73_element_matching.ipynb)
#
# # 🟡 Medium: Multi-Constraint Element Matching
#
# > Algorithm problem (no PyTorch). LeetCode class-mode. Source: Alibaba 2026-05-23.
#
# Given three length-`n` arrays `a`, `b`, `c` (where each `c[j]` is a **1-indexed** index into `b`), count ordered pairs `(i, j)` such that:
#
# - `1 <= i <= j <= n`;
# - `a[i] == b[c[j]]`.
#
# ### Signature
# ```python
# from typing import List
#
# class Solution:
#     def count_pairs(self, a: List[int], b: List[int], c: List[int]) -> int:
#         # c[j] is 1-indexed into b
#         ...
# ```
#
# ### Rules
# - `1 <= n <= 1e5`, `1 <= a[i], b[i] <= 1e9`, `1 <= c[j] <= n`.
# - Target `O(n)` per test with a hash map.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from typing import List
from collections import defaultdict

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def count_pairs(self, a: List[int], b: List[int], c: List[int]) -> int:
        pass

# %%
# 🧪 Debug
print(Solution().count_pairs([1, 2, 1, 2, 1], [2, 1, 3, 1, 2], [2, 1, 5, 4, 3]))  # expected: 5
print(Solution().count_pairs([7, 7, 7], [1, 2, 7], [3, 3, 3]))                    # expected: 6

# %%
from torch_judge import check
check('element_matching')
