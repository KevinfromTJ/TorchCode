# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/96_pca_anomaly_oppo260808.ipynb)
#
# # 🟡 Medium: PCA 重构误差异常检测
#
# > 来源：OPPO 机考 AI 算法岗 2026-08-08（第 2 题）
#
# 给定一批正常样本组成的训练矩阵 `train` 和待检测矩阵 `test`（两者都可能含缺失值 `None`/`NaN`）。用 PCA 重构误差做异常检测，步骤如下：
#
# 1. 用**训练矩阵**每列的均值填补 `train` 与 `test` 的缺失值（仅用训练集统计量）。
# 2. 在 `train` 上 `fit` 一个 `StandardScaler`，对两者做标准化。
# 3. 用 `PCA(n_components=0.95, svd_solver='full')` 在标准化后的 `train` 上 `fit`，对两者 `transform` 后再 `inverse_transform` 得到重构。
# 4. 重构误差 = 每个特征差的平方和。
# 5. 阈值 = `np.percentile(train_errors, 95)`；某个 `test` 样本误差**严格大于**阈值记为异常 `1`，否则 `0`。
#
# 按 `test` 的顺序返回标签列表。
#
# ### 函数签名
# ```python
# from typing import List, Optional
#
# def detect_anomaly(train: List[List[Optional[float]]],
#                    test: List[List[Optional[float]]]) -> List[int]:
#     ...
# ```
#
# *提示：* `np.array(..., dtype=float)` 会把 `None` 变为 `nan`。`means = np.nanmean(train, axis=0)`，用 `means[col]` 填补 `train` 和 `test` 中的 `nan`。`StandardScaler().fit(train)` 后对两者 `transform`。`PCA(n_components=0.95, svd_solver='full').fit(train_scaled)`，重构用 `pca.inverse_transform(pca.transform(X))`。误差 `np.sum((X - X_rec)**2, axis=1)`。`threshold = np.percentile(train_err, 95)`，返回 `(test_err > threshold).astype(int)`。

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def detect_anomaly(train, test):
    pass

# %%
train = [[1, 2], [2, 4.1], [3, 5.9], [4, 8.1], [5, 10]]
test = [[2.5, 5.0], [2.5, 10.0], [3.0, None]]
print(detect_anomaly(train, test))   # expected: [0, 1, 0]

# %%
from torch_judge import check
check('pca_anomaly_oppo260808')
