# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/56_self_distillation_loss.ipynb)
#
# # 🟠 Medium: Self-Distillation Loss
#
# Implement a simple **self-distillation** objective with a main head and an auxiliary head.
#
# ### Signature
# ```python
# def self_distillation_loss(main_logits, aux_logits, targets,
#                            temperature=2.0, ce_weight=1.0, distill_weight=0.5):
#     # main_logits, aux_logits: (B, C)
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def self_distillation_loss(main_logits, aux_logits, targets,
                           temperature=2.0, ce_weight=1.0, distill_weight=0.5):
    pass

# %%
main = torch.randn(4, 6)
aux = torch.randn(4, 6)
targets = torch.randint(0, 6, (4,))
print('Loss:', self_distillation_loss(main, aux, targets))

# %%
from torch_judge import check
check('self_distillation_loss')
