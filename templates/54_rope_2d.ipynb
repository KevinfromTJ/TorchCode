# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/54_rope_2d.ipynb)
#
# # 🔴 Hard: 2D Rotary Position Embedding (2D RoPE)
#
# Implement **2D RoPE** for flattened image patch tokens.
#
# ### Signature
# ```python
# def apply_2d_rope(q, k, height, width):
#     # q, k: (B, H*W, D)
#     # D must be divisible by 4
#     # returns rotated (q, k)
# ```
#
# ### Idea
# - first half of channels uses row positions
# - second half of channels uses column positions
# - each half applies standard 1D RoPE independently

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def apply_2d_rope(q, k, height, width):
    pass

# %%
# 🧪 Debug
q = torch.randn(1, 16, 32)
k = torch.randn(1, 16, 32)
qr, kr = apply_2d_rope(q, k, height=4, width=4)
print('Q shape:', qr.shape)
print('Norm preserved:', torch.allclose(q.norm(dim=-1), qr.norm(dim=-1), atol=1e-4))

# %%
from torch_judge import check
check('rope_2d')
