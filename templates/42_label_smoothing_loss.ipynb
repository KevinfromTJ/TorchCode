# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/42_label_smoothing_loss.ipynb)
#
# # 🟡 Medium: Label Smoothing Loss
#
# Implement **cross-entropy with label smoothing**.
#
# $$
# q = (1-\epsilon) \cdot 	ext{one\_hot}(y) + \epsilon / C
# $$
#
# ### Signature
# ```python
# def label_smoothing_loss(logits: torch.Tensor, targets: torch.Tensor, smoothing: float = 0.1) -> torch.Tensor:
#     # logits: (B, C), targets: (B,)
#     # Returns: scalar mean loss
# ```
#
# ### Rules
# - Do **NOT** use `F.cross_entropy(..., label_smoothing=...)`
# - Use `log_softmax` or an equivalent stable implementation
# - Match PyTorch-style smoothing over **all** classes

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def label_smoothing_loss(logits: torch.Tensor, targets: torch.Tensor, smoothing: float = 0.1) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
logits = torch.randn(4, 5)
targets = torch.tensor([0, 1, 2, 3])
print('Loss:', label_smoothing_loss(logits, targets, smoothing=0.1))
print('Ref: ', F.cross_entropy(logits, targets, label_smoothing=0.1))

# %%
# ✅ SUBMIT
from torch_judge import check
check('label_smoothing_loss')
