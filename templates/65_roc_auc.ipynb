# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/65_roc_auc.ipynb)
#
# # 🟡 Medium: ROC Curve & AUC
#
# Given prediction **scores** and binary **labels**, build the ROC curve and compute the area under it (**AUC**) from scratch.
#
# $$\text{TPR} = \frac{TP}{P}, \quad \text{FPR} = \frac{FP}{N}, \quad \text{AUC} = \int_0^1 \text{TPR}\,d(\text{FPR})$$
#
# ### Signature
# ```python
# def roc_auc(scores: Tensor, labels: Tensor):
#     # scores: (N,) float prediction scores (higher = more positive)
#     # labels: (N,) in {0, 1}
#     # Returns: (fpr, tpr, auc) — fpr/tpr are 1-D tensors, auc is a scalar tensor
# ```
#
# ### Rules
# - Do NOT use `sklearn` (or any external metric library)
# - Sort by score, sweep the threshold, collapse tied scores into a single ROC point
# - Curve starts at (0, 0) and ends at (1, 1); integrate with the trapezoidal rule (`torch.trapz`)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def roc_auc(scores, labels):
    pass

# %%
# 🧪 Debug
scores = torch.tensor([0.9, 0.8, 0.7, 0.2, 0.1, 0.05])
labels = torch.tensor([1, 1, 1, 0, 0, 0])
fpr, tpr, auc = roc_auc(scores, labels)
print('AUC:', auc, '(expected 1.0 for perfect separation)')

# %%
from torch_judge import check
check('roc_auc')
