# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/63_masked_perplexity.ipynb)
#
# # 🟡 Medium: Masked Perplexity
#
# Compute **perplexity** of a language model over a batch, ignoring padded / prompt positions via a mask.
#
# $$\text{PPL} = \exp\!\left(\frac{\sum_{b,t} m_{b,t}\,\big(-\log p_\theta(y_{b,t})\big)}{\sum_{b,t} m_{b,t}}\right)$$
#
# ### Signature
# ```python
# def masked_perplexity(logits: Tensor, targets: Tensor, mask: Tensor) -> Tensor:
#     # logits: (B, T, V) float, targets: (B, T) long, mask: (B, T) in {0, 1}
#     # Returns: scalar perplexity (exp of the mask-averaged token NLL)
# ```
#
# ### Rules
# - Do NOT use `F.cross_entropy` / `nn.CrossEntropyLoss`
# - Do NOT use `torch.gather` — select the target log-prob with plain indexing (flatten + `arange`)
# - Must be numerically stable (use the logsumexp trick)
# - Keep it to a single function containing the core computation

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def masked_perplexity(logits, targets, mask):
    pass

# %%
# 🧪 Debug
B, T, V = 2, 5, 8
logits = torch.randn(B, T, V)
targets = torch.randint(0, V, (B, T))
mask = torch.tensor([[1, 1, 1, 0, 0], [1, 1, 1, 1, 0]], dtype=torch.float32)
print('PPL:', masked_perplexity(logits, targets, mask))

# %%
from torch_judge import check
check('masked_perplexity')
