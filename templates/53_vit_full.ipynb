# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/53_vit_full.ipynb)
#
# # 🔴 Hard: Vision Transformer (ViT) Full Model
#
# Implement a simplified but complete **Vision Transformer** classifier.
#
# ### Signature
# ```python
# class VisionTransformer(nn.Module):
#     def __init__(self, img_size, patch_size, in_channels, num_classes,
#                  embed_dim, depth, num_heads, mlp_ratio=4.0): ...
#     def forward(self, x):
#         # x: (B, C, H, W)
#         # returns: (B, num_classes)
# ```
#
# ### Requirements
# - Patch embedding
# - learnable `cls_token`
# - learnable `pos_embed`
# - Transformer encoder blocks
# - final classifier head from cls token

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn as nn

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class VisionTransformer(nn.Module):
    def __init__(self, img_size, patch_size, in_channels, num_classes,
                 embed_dim, depth, num_heads, mlp_ratio=4.0):
        super().__init__()
        pass

    def forward(self, x):
        pass

# %%
# 🧪 Debug
model = VisionTransformer(img_size=32, patch_size=8, in_channels=3, num_classes=10, embed_dim=64, depth=2, num_heads=4)
x = torch.randn(2, 3, 32, 32)
print('Logits:', model(x).shape)

# %%
from torch_judge import check
check('vit_full')
