# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/69_cycle_flip_maintenance.ipynb)
#
# # 🔴 Hard: Single-Cycle Graph Alarm Flip
#
# > Algorithm problem (no PyTorch). LeetCode class-mode.
#
# An alarm network has `N` nodes and `N` undirected edges, is connected, and has no self-loops or multi-edges — so it is a tree plus one edge (exactly one simple cycle). Node `i` starts at alarm state `b_i` (`0` off, `1` ringing). Maintaining edge `i` (cost `c_i`) **flips both endpoints**.
#
# A maintenance plan is a subset of edges (each maintained at most once). A plan is **feasible** if afterwards every node is `0`. Its cost is the sum of maintained edge costs.
#
# Return the **minimum feasible cost** and the **number of minimum-cost feasible plans**.
#
# ### Signature
# ```python
# from typing import List
#
# class Solution:
#     def solve(self, n: int, state: List[int], edges: List[List[int]]) -> List[int]:
#         # edges[i] = [u, v, c] with 1-indexed u, v
#         # return [min_cost, count], or [-1, 0] if infeasible
# ```
#
# ### Rules
# - `3 <= N <= 2e5`, `b_i in {0,1}`, `1 <= c_i <= 1e9`, graph connected, no self-loops/multi-edges.
# - Target `O(N)`.
#
# *Hint:* feasibility depends on the total parity; there are exactly two feasible plans, differing by the unique cycle's edges.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import sys
from typing import List
sys.setrecursionlimit(1 << 20)

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def solve(self, n: int, state: List[int], edges: List[List[int]]) -> List[int]:
        pass

# %%
# 🧪 Debug
print(Solution().solve(5, [0, 1, 1, 1, 1], [[1, 2, 4], [2, 3, 2], [3, 1, 7], [3, 4, 5], [4, 5, 1]]))  # [3, 1]
print(Solution().solve(3, [1, 0, 0], [[1, 2, 1], [2, 3, 1], [3, 1, 1]]))  # [-1, 0]

# %%
from torch_judge import check
check('cycle_flip_maintenance')
