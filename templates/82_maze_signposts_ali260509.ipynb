# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/82_maze_signposts_ali260509.ipynb)
#
# # 🟡 Medium: Maze Signposts
#
# > Source: Alibaba 2026-05-09 (Problem 2).
#
# Corridor of positions `1..n`, each holding a sign `'L'` or `'R'`. Drop a ball at start `s`: it reads the sign at its current cell and jumps in that direction to the **first not-yet-visited** position, exiting off the left (past 0) or right (past n+1). For every start `s = 1..n`, output the exit side as a string.
#
# ### Signature
# ```python
# class Solution:
#     def exit_sides(self, signs: str) -> str:
#         ...
# ```
#
# *Hint:* exactly `cntL` (number of `'L'` signs) balls exit left, and they are the leftmost `cntL` starts. So the answer is `'L'*cntL + 'R'*(n-cntL)`.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
# no imports needed

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def exit_sides(self, signs: str) -> str:
        pass

# %%
# 🧪 Debug
print(Solution().exit_sides('LRRLL'))   # expected: LLLRR
print(Solution().exit_sides('LLL'))     # expected: LLL

# %%
from torch_judge import check
check('maze_signposts_ali260509')
