# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/66_instance_publish.ipynb)
#
# # 🟢 Easy: Instance State Publish Operation
#
# > Algorithm problem (no PyTorch). LeetCode class-mode.
#
# Multi is running a grayscale release over instances numbered `1..n`, each in state `'0'` (old) or `'1'` (new). Exactly one operation was applied:
#
# 1. pick a non-empty range `[L, R]`
# 2. pick a target value `V` (`'0'` or `'1'`)
# 3. set every instance in `[L, R]` to `V` (it must change **at least one** instance)
#
# Given the before string `A` and after string `B` (the log is lost), decide whether the operation `(L, R, V)` is **uniquely** determined.
#
# ### Signature
# ```python
# class Solution:
#     def find_operation(self, a: str, b: str) -> str:
#         # return '{L} {R} {V}' with 1-indexed L, R (e.g. '2 4 1'), or '-1'
# ```
#
# ### Rules
# - Two operations are different if **any** of `L`, `R`, `V` differ (even if the result is identical).
# - Inputs guarantee at least one valid operation exists (so `A != B`).
# - Target `O(n)` time, `O(1)` extra space.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def find_operation(self, a: str, b: str) -> str:
        pass

# %%
# 🧪 Debug
print(Solution().find_operation('00000', '01110'))  # expected: 2 4 1
print(Solution().find_operation('01000', '01110'))  # expected: -1

# %%
from torch_judge import check
check('instance_publish')
