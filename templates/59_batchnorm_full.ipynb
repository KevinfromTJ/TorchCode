# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/59_batchnorm_full.ipynb)
#
# # 🔴 Hard: BatchNorm Full Module

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn as nn

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class MyBatchNorm1d(nn.Module):
    def __init__(self, num_features, eps=1e-5, momentum=0.1):
        super().__init__()
        pass

    def forward(self, x):
        pass

# %%
# 🧪 Debug
m = MyBatchNorm1d(6)
x = torch.randn(8, 6)
print('Output:', m(x).shape)

# %%
from torch_judge import check
check('batchnorm_full')
