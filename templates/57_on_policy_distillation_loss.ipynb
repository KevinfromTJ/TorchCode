# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/57_on_policy_distillation_loss.ipynb)
#
# # 🔴 Hard: On-Policy Distillation Loss
#
# Implement a masked token-level **on-policy distillation** loss.
#
# ### Signature
# ```python
# def on_policy_distillation_loss(student_logits, teacher_logits, completion_mask,
#                                 temperature=2.0):
#     # student_logits, teacher_logits: (B, T, V)
#     # completion_mask: (B, T)
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def on_policy_distillation_loss(student_logits, teacher_logits, completion_mask,
                                temperature=2.0):
    pass

# %%
student = torch.randn(2, 4, 8)
teacher = torch.randn(2, 4, 8)
mask = torch.tensor([[1, 1, 1, 1], [1, 1, 0, 0]], dtype=torch.float32)
print('Loss:', on_policy_distillation_loss(student, teacher, mask))

# %%
from torch_judge import check
check('on_policy_distillation_loss')
