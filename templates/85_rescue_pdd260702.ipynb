# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/85_rescue_pdd260702.ipynb)
#
# # 🟡 Medium: Rescue Operation
#
# > Source: Pinduoduo 2026-07-02 (Problem 2).
#
# `n` guards (`1..n`). Guard `j` watches a set of regions; a region is protected while any alive guard watches it. A guard in an **unwatched** region can be killed (single kill). Two guards who watch **only each other** (and are each other's **sole** watcher) can be killed together (double kill). Peel to a fixed point.
#
# Return `"SUCCESS"` if every guard is killed, else the minimum number of survivors.
#
# ### Signature
# ```python
# class Solution:
#     def min_remaining(self, n: int, monitors: list) -> object:
#         ...
# ```
# `monitors[j]` (0-indexed, guard `j+1`) is the list of 1-indexed regions/guards it watches.
#
# *Hint:* keep `monitored_by[r]` = set of alive watchers. Kill anyone with empty `monitored_by`; if none, kill a mutual-only pair `monitored_by[i]=={j}`, `monitored_by[j]=={i}`. Repeat until stable.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
# no imports needed

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def min_remaining(self, n, monitors):
        pass

# %%
# 🧪 Debug
print(Solution().min_remaining(2, [[2], []]))    # expected: SUCCESS
print(Solution().min_remaining(2, [[2], [1]]))   # expected: SUCCESS (mutual pair)
print(Solution().min_remaining(3, [[2], [3], [1]]))  # expected: 3 (irreducible cycle)

# %%
from torch_judge import check
check('rescue_pdd260702')
