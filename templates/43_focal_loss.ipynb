# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/43_focal_loss.ipynb)
#
# # 🟡 Medium: Focal Loss
#
# Implement **binary focal loss** for imbalanced classification.
#
# $$
# 	ext{FL}(p_t) = -(1 - p_t)^\gamma \log(p_t)
# $$
#
# ### Signature
# ```python
# def focal_loss(logits: torch.Tensor, targets: torch.Tensor, gamma: float = 2.0, alpha: float | None = None) -> torch.Tensor:
#     # logits, targets: same shape
#     # targets are 0/1 or soft labels in [0, 1]
#     # Returns: scalar mean loss
# ```
#
# ### Rules
# - Use logits input, not probabilities
# - When `gamma=0`, the loss should reduce to BCE-with-logits if `alpha=None`
# - If `alpha` is given, weight positive and negative examples differently

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def focal_loss(logits: torch.Tensor, targets: torch.Tensor, gamma: float = 2.0, alpha: float | None = None) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
logits = torch.tensor([2.0, -2.0, 0.0, -1.5])
targets = torch.tensor([1.0, 0.0, 1.0, 0.0])
print('Loss:', focal_loss(logits, targets, gamma=2.0))
print('BCE :', F.binary_cross_entropy_with_logits(logits, targets))

# %%
# ✅ SUBMIT
from torch_judge import check
check('focal_loss')
