# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/83_xab_ali260509.ipynb)
#
# # 🔴 Hard: xab (Max XOR Pair Count)
#
# > Source: Alibaba 2026-05-09 (Problem 3).
#
# Given a fixed `x` and ranges `a ∈ [la, ra]`, `b ∈ [lb, rb]` (values up to ~1e9), choose `(a, b)` to **maximize** `x XOR a XOR b`, then **count how many distinct pairs** `(a, b)` attain that maximum.
#
# ### Signature
# ```python
# class Solution:
#     def count_best_pairs(self, x: int, la: int, ra: int, lb: int, rb: int) -> int:
#         ...
# ```
#
# *Hint:* digit DP from the high bit. Carry a 16-state mask of "still tight against la/ra/lb/rb" flags (`f[15]=1` initially). At each bit, if any transition can make the XOR bit 1, greedily keep only those; else keep the 0-bit transitions. Answer = `sum(f)`.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
# no imports needed

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def count_best_pairs(self, x: int, la: int, ra: int, lb: int, rb: int) -> int:
        pass

# %%
# 🧪 Debug
print(Solution().count_best_pairs(0, 1, 2, 0, 2))   # expected: 2
print(Solution().count_best_pairs(5, 1, 7, 6, 9))   # expected: 2

# %%
from torch_judge import check
check('xab_ali260509')
