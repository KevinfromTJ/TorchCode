# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/64_gd_minimize.ipynb)
#
# # 🟡 Medium: Gradient Descent Minimizer
#
# Find the minimizer of an arbitrary differentiable function using **plain gradient descent** and PyTorch autograd.
#
# $$x_{k+1} = x_k - \eta \, \nabla f(x_k)$$
#
# ### Signature
# ```python
# def gradient_descent_minimize(f, x0: Tensor, lr: float = 0.1, steps: int = 100) -> Tensor:
#     # f:  callable mapping a tensor to a scalar tensor
#     # x0: starting point
#     # Returns: the optimized point (detached from the graph, same shape as x0)
# ```
#
# ### Rules
# - Use `autograd` (`backward()`) to obtain gradients — do NOT hand-derive them
# - Update parameters under `torch.no_grad()` and clear the gradient between steps
# - Do NOT mutate the input `x0` in place; return a detached result

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def gradient_descent_minimize(f, x0, lr=0.1, steps=100):
    pass

# %%
# 🧪 Debug
f = lambda x: (x - 3.0) ** 2
x = gradient_descent_minimize(f, torch.tensor([0.0]), lr=0.1, steps=200)
print('argmin:', x, '(expected ~3.0)')

# %%
from torch_judge import check
check('gd_minimize')
