# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/55_kd_loss.ipynb)
#
# # 🟠 Medium: Knowledge Distillation (KD) Loss
#
# Implement the classic **teacher-student knowledge distillation** loss.
#
# ### Signature
# ```python
# def kd_loss(student_logits, teacher_logits, targets,
#             temperature=2.0, alpha=0.5):
#     # student_logits, teacher_logits: (B, C)
#     # targets: (B,)
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def kd_loss(student_logits, teacher_logits, targets,
            temperature=2.0, alpha=0.5):
    pass

# %%
student = torch.randn(4, 6)
teacher = torch.randn(4, 6)
targets = torch.randint(0, 6, (4,))
print('Loss:', kd_loss(student, teacher, targets))

# %%
from torch_judge import check
check('kd_loss')
