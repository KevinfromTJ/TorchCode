# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/81_signed_permutation_ali260509.ipynb)
#
# # 🟡 Medium: Signed Permutation (Sum Zero)
#
# > Source: Alibaba 2026-05-09 (Problem 1).
#
# Given `n`, build a length-`n` array where the **absolute values** `|a_i|` form a permutation of `1..n`, every `a_i != 0`, and the total **sum is 0**. Return `[]` if impossible.
#
# ### Signature
# ```python
# from typing import List
#
# class Solution:
#     def construct(self, n: int) -> List[int]:
#         ...
# ```
#
# *Hint:* the sum `1+2+...+n = n(n+1)/2` must be **even** to split into `+`/`-` halves, i.e. impossible when `n % 4 in {1, 2}`. Otherwise tile quadruples `(x, -(x+1), -(x+2), x+3)` (each sums to 0); for `n % 4 == 3` start with `[1, 2, -3]` then tile from `x=4`.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from typing import List

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def construct(self, n: int) -> List[int]:
        pass

# %%
# 🧪 Debug
print(Solution().construct(2))   # expected: []
print(Solution().construct(3))   # e.g. [1, 2, -3]
print(Solution().construct(4))   # e.g. [1, -2, -3, 4]

# %%
from torch_judge import check
check('signed_permutation_ali260509')
