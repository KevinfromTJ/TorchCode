# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/49_tokenizer_full.ipynb)
#
# # 🔴 Hard: Tokenizer (Complete BPE Implementation)
#
# Implement a complete mini tokenizer: BPE training + vocab ids + encode/decode + special tokens.
#
# ### Signature
# ```python
# class FullBPETokenizer:
#     def __init__(self): ...
#     def train(self, corpus: list[str], num_merges: int): ...
#     def encode(self, text: str, add_special_tokens=True) -> list[int]: ...
#     def decode(self, token_ids: list[int], skip_special_tokens=True) -> str: ...
# ```
#
# ### Features
# - Learn BPE merges with `</w>` as word-end marker
# - Build `token_to_id` and `id_to_token`
# - Include `<pad>`, `<unk>`, `<bos>`, `<eos>`
# - Support round-trip encode/decode for known words

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
# No imports needed

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class FullBPETokenizer:
    def __init__(self):
        pass

    def train(self, corpus, num_merges):
        pass

    def encode(self, text, add_special_tokens=True):
        pass

    def decode(self, token_ids, skip_special_tokens=True):
        pass

# %%
# 🧪 Debug
tok = FullBPETokenizer()
tok.train(['low', 'lower', 'lowest', 'newest'], num_merges=10)
ids = tok.encode('low lower')
print('Encoded ids:', ids)
print('Decoded:', tok.decode(ids))
print('Vocab size:', len(tok.token_to_id))

# %%
# ✅ SUBMIT
from torch_judge import check
check('tokenizer_full')
