# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/86_fly_catching_pdd260702.ipynb)
#
# # 🟡 Medium: Catch the Fly
#
# > Source: Pinduoduo 2026-07-02 (Problem 3).
#
# `n` rooms form a **functional graph**: from room `i` a fly moves to room `a[i]`. Placing a trap in room `i` costs `c[i]`. A fly starting anywhere eventually enters a cycle and loops forever, so it is caught **iff every cycle contains a trapped room**. Return the minimum total cost.
#
# ### Signature
# ```python
# from typing import List
#
# class Solution:
#     def min_cost(self, a: List[int], c: List[int]) -> int:
#         ...
# ```
# `a` is 0-indexed (`a[i] in 0..n-1`).
#
# *Hint:* every node leads into exactly one cycle. Find cycles by topological peeling (remove in-degree-0 nodes repeatedly); the survivors are the cycles. Sum the minimum `c` on each cycle.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from typing import List
from collections import deque

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class Solution:
    def min_cost(self, a: List[int], c: List[int]) -> int:
        pass

# %%
# 🧪 Debug
# rooms 1..4 with (1-indexed) a=[2,4,2,2] -> 0-indexed a=[1,3,1,1], c=[1,10,2,10]
print(Solution().min_cost([1, 3, 1, 1], [1, 10, 2, 10]))   # expected: 10

# %%
from torch_judge import check
check('fly_catching_pdd260702')
